# %% [markdown]
# ## Importing Necessary libaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ### Reading CSV File "cricket_clean_dataset.csv"

# %%
df = pd.read_csv("cricket_clean_dataset.csv")
df
# Out:
#        Player_Names      Country  Start_Year  End_Year  Matches  Innings  \
# 0     SR Tendulkar         India        1989      2012      463      452
# 1    KC Sangakkara     Sri Lanka        2000      2015      404      380
# 2          V Kohli         India        2008      2025      302      290
# 3       RT Ponting     Australia        1995      2012      375      365
# 4    ST Jayasuriya     Sri Lanka        1989      2011      445      433
# ..              ...          ...         ...       ...      ...      ...
# 441       DS Airee         Nepal        2018      2025       64       60
# 442       DS Smith   West Indies        2003      2013       47       45
# 443     JK Kamande         Kenya        1999      2011       86       72
# 444      IDS Smith   New Zealand        1980      1992       98       77
# 445   C Kieswetter       England        2010      2013       46       40
#
#      Not_Out  Total_Runs  Highest_Score  Batting_Average  Ball_Faced  \
# ...

# %% [markdown]
# ### Checking the Shape of the DataFrame

# %%
df.shape
# Out:
# (446, 14)

# %% [markdown]
# ### Observation:
# #### The DataFrame is having 446 rows & 14 columns

# %% [markdown]
# ## Changing data type of Start_Year & End_Year

# %%
df[["Start_Year","End_Year"]] = df[["Start_Year","End_Year"]].astype(object)

# %%
df['Start_Year'] = pd.to_datetime(df['Start_Year'], format='%Y')
df['End_Year'] = pd.to_datetime(df['End_Year'], format='%Y')

print(df[['Start_Year', 'End_Year']].dtypes)
# Out:
# Start_Year    datetime64[ns]
# End_Year      datetime64[ns]
# dtype: object

# %% [markdown]
# ## Checking Information about this DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 446 entries, 0 to 445
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Player_Names     446 non-null    object
#  1   Country          446 non-null    object
#  2   Start_Year       446 non-null    datetime64[ns]
#  3   End_Year         446 non-null    datetime64[ns]
#  4   Matches          446 non-null    int64
#  5   Innings          446 non-null    int64
#  6   Not_Out          446 non-null    int64
#  7   Total_Runs       446 non-null    int64
#  8   Highest_Score    446 non-null    int64
#  9   Batting_Average  446 non-null    float64
#  10  Ball_Faced       446 non-null    int64
#  11  Strike_Rate      446 non-null    float64
#  12  100's            446 non-null    int64
#  13  50's             446 non-null    int64
# dtypes: datetime64[ns](2), float64(2), int64(8), object(2)
# memory usage: 48.9+ KB

# %% [markdown]
# ### Observation:-
# #### In this DataFrame there are 2 float,8 int, and 4 object type values

# %% [markdown]
# ## Checking Stastical Description

# %%
# For Numerical Columns
df.describe()
# Out:
#                           Start_Year                       End_Year  \
# count                            446                            446
# mean   2001-07-30 21:54:04.843049344  2011-12-25 01:17:29.327354368
# min              1971-01-01 00:00:00            1981-01-01 00:00:00
# 25%              1993-01-01 00:00:00            2004-01-01 00:00:00
# 50%              2003-01-01 00:00:00            2014-01-01 00:00:00
# 75%              2012-01-01 00:00:00            2023-01-01 00:00:00
# max              2023-01-01 00:00:00            2025-01-01 00:00:00
# std                              NaN                            NaN
#
#           Matches     Innings     Not_Out    Total_Runs  Highest_Score  \
# count  446.000000  446.000000  446.000000    446.000000     446.000000
# mean   127.986547  116.011211   15.762332   3372.015695     122.854260
# min     25.000000   25.000000    0.000000   1054.000000      47.000000
# ...

# %%
# For Object Columns
df.describe(include = "object")
# Out:
#          Player_Names      Country
# count             446          446
# unique            446           22
# top     SR Tendulkar   New Zealand
# freq                1           46

# %%
#df["Player_Names"].str.upper()

# %% [markdown]
# ## Checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Observation:-
# #### There is no duplicate value

# %% [markdown]
# ## Cheaking for the null values

# %%
df.isnull().sum()
# Out:
# Player_Names       0
# Country            0
# Start_Year         0
# End_Year           0
# Matches            0
# Innings            0
# Not_Out            0
# Total_Runs         0
# Highest_Score      0
# Batting_Average    0
# Ball_Faced         0
# Strike_Rate        0
# 100's              0
# 50's               0
# dtype: int64

# %% [markdown]
# ### Observation:-
# #### There is no null value

# %% [markdown]
# ## Checking for number of unique values in the data.

# %%
df.nunique()
# Out:
# Player_Names       446
# Country             22
# Start_Year          52
# End_Year            44
# Matches            205
# Innings            191
# Not_Out             58
# Total_Runs         417
# Highest_Score      136
# Batting_Average    417
# Ball_Faced         432
# Strike_Rate        422
# 100's               30
# 50's                72
# dtype: int64

# %% [markdown]
# ### Observation:-
# #### The dataset includes unique values like
# - 446, Player_Names
# - 22 Country,
# - 52 Start_Year,
# - 44 End_Year,
# - 205 Matches,
# - 191 Innings,
# - 58 Not_Out,
# - 417 Total_Runs,
# - 136 Highest_Score,
# - 417 Batting_Average,
# - 432 Ball_Faced,
# - 422 Strike_Rate,
# - 30 => 100's
# - 72 => 50's

# %% [markdown]
# # Checking Correlation for numerical columns

# %%
df.corr(numeric_only=True)
# Out:
#                   Matches   Innings   Not_Out  Total_Runs  Highest_Score  \
# Matches          1.000000  0.982468  0.782864    0.865659       0.282353
# Innings          0.982468  1.000000  0.698482    0.926484       0.367808
# Not_Out          0.782864  0.698482  1.000000    0.537113       0.001753
# Total_Runs       0.865659  0.926484  0.537113    1.000000       0.560191
# Highest_Score    0.282353  0.367808  0.001753    0.560191       1.000000
# Batting_Average  0.082883  0.159108  0.061246    0.443992       0.614595
# Ball_Faced       0.852002  0.917204  0.529204    0.978119       0.491884
# Strike_Rate      0.102926  0.080020  0.083075    0.129226       0.344959
# 100's            0.574837  0.650062  0.228707    0.840362       0.674402
# 50's             0.794468  0.866328  0.486460    0.966815       0.527173
#
#                  Batting_Average  Ball_Faced  Strike_Rate     100's      50's
# Matches                 0.082883    0.852002     0.102926  0.574837  0.794468
# ...

# %%
#df.corr(numeric_only = True)

# %% [markdown]
# # Steps Involved in Exploratory Data Analysis
#
# 1. **Univariate Analysis**
#   A. Discrete Data (i.e. Categorical or Numerical Discrete Columns)
#     - Statistical Non Visual Analysis
# 		- Purpose: Helps us describe and summarize the data
# 		- count, nunique, unique, value_counts
# 	- Visual Analysis
# 		- Purpose: Helps us understand how the data is distributed and Outliers
# 		- Bar/Count Plot
#
#   B. Continuous Numerical Data (i.e. Real Numerical)
#     - Statistical Non Visual Analysis
# 		- Purpose: Helps us describe and summarize the data
# 		- min, max, sum, mean, median, var, std, range, iqr
# 	- Visual Analysis
# 		- Purpose: Helps us understand the Distribution of data and Outliers
# 		- Histogram Plot, KDE Plot and Box Plot
#
# 2. **Bivariate Analysis (Purpose - Helps identify the relationships)**
#   A. Continuous Numerical vs Continuous Numerical Data
#     - Statistical Non Visual Analysis
# 		- Purpose: Is there any relationship between two variables - Linear or non Linear relationship?
# 		- Pearson Correlation Coefficient
# 	- Visual Analysis
# 		- Scatter Plot
#
#   B. Continuous Numerical vs Discrete Data
#     - Statistical Non Visual Analysis
# 		- Purpose: How many discrete groups are there and Are the individuals in the groups independent or dependent?
# 		- Compare the Mean, Median, Std of the groups
# 	- Visual Analysis
# 		- Box Plots and Histogram Plots
#
#   C. Discrete vs Discrete Data
#     - Statistical Non Visual Analysis
# 		- Purpose: Are the individuals in the groups independent or dependent?
# 		- Cross Tabs (i.e. Frequency Tables)
# 	- Visual Analysis
# 		- Stacked Bar Plot, Unstacked Bar Plot

# %% [markdown]
# ### 1. Univariate Analysis - Statistical Non Visual Analysis

# %% [markdown]
# ### For Numerical Columns

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64'])

# %%
def numerical_univariate_analysis(numerical_data):
    for col_name in numerical_data:
        print("*"*10, col_name, "*"*10)
        print(numerical_data[col_name].agg(['min', 'max', 'mean', 'median', 'std']))
        print()

# %%
numerical_univariate_analysis(numerical_cols)
# Out:
# ********** Matches **********
# min        25.000000
# max       463.000000
# mean      127.986547
# median    105.000000
# std        82.021153
# Name: Matches, dtype: float64
#
# ********** Innings **********
# min        25.000000
# max       452.000000
# mean      116.011211
# median     88.500000
# std        75.065888
# Name: Innings, dtype: float64
#
# ********** Not_Out **********
# min        0.000000
# max       84.000000
# mean      15.762332
# median    11.000000
# std       14.683539
# Name: Not_Out, dtype: float64
#
# ********** Total_Runs **********
# min        1054.000000
# max       18426.000000
# mean       3372.015695
# median     2299.000000
# std        2674.473829
# Name: Total_Runs, dtype: float64
#
# ********** Highest_Score **********
# min        47.000000
# max       264.000000
# mean      122.854260
# median    119.000000
# std        32.874276
# Name: Highest_Score, dtype: float64
#
# ********** Batting_Average **********
# min       13.300000
# ...

# %% [markdown]
# ### For Categorical Columns

# %%
categorical_cols = df.select_dtypes(include=['object'])

# %%
def categorical_univariate_analysis(categorical_data):
    for col_name in categorical_data:
        print("*"*15, col_name, "*"*15)
        print(categorical_data[col_name].agg(['count', 'nunique', 'unique']))
        print()

# %%
categorical_univariate_analysis(categorical_cols)
# Out:
# *************** Player_Names ***************
# count                                                    446
# nunique                                                  446
# unique     [SR Tendulkar , KC Sangakkara , V Kohli , RT P...
# Name: Player_Names, dtype: object
#
# *************** Country ***************
# count                                                    446
# nunique                                                   22
# unique     [India, Sri Lanka, Australia, Pakistan, South ...
# Name: Country, dtype: object

# %% [markdown]
# ## Univariate Plots
# - Numerical Columns

# %%
for col in numerical_cols:
    
    
    # Plots
    plt.figure(figsize=(12, 4))
    
    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(df[col], kde=True, bins=20, color="skyblue")
    plt.title(f"{col} - Distribution")
    
    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col], color="lightgreen")
    plt.title(f"{col} - Boxplot")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Univariate Plots
# - Categorical Columns

# %%
for col in categorical_cols:
    
    plt.figure(figsize=(8, 4))
    top_values = df[col].value_counts().head(5)
    sns.barplot(x=top_values.values,y=top_values.index, hue = top_values.index,legend=True, palette = "cool")
    plt.title(f"Top 5 {col}")
    plt.xlabel("Count")
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

# Get top 5 countries
top5 = df['Country'].value_counts().head(5)

# Plot pie chart
plt.figure(figsize=(8, 6))
top5.plot(kind='pie', autopct='%1.f%%', startangle=90, colormap='Set3')
plt.title("Top 5 Countries Representation")
plt.ylabel("")  # Remove default y-label
plt.tight_layout()
plt.show()

# %%
df['Career_Length'] = (df['End_Year'].dt.year - df['Start_Year'].dt.year)

# %% [markdown]
# ## 2. Bivariate Analysis

# %% [markdown]
#  ##  Count of Players by Country

# %%
country_counts = df['Country'].value_counts()
plt.figure(figsize=(8,5))
ax = sns.barplot(x=country_counts.values, y=country_counts.index, palette='cool')
for i in ax.containers:
    ax.bar_label(i)
plt.title("Number of Players per Country")
plt.xlabel("Number of Players")
plt.ylabel("Country")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation:-
# - Top cricketing nations: New Zealand, Australia, Pakistan, India, West Indies, and England each have 40+ players.
#
# - Mid-tier nations: Sri Lanka and South Africa have moderate representation.
#
# - Lower-tier nations: Zimbabwe, Bangladesh, Afghanistan, and others contribute fewer players.

# %% [markdown]
# ### Which player has scored the highest total runs according to the Top 10 Run Scorers ?

# %%
top_runs = df.nlargest(10, 'Total_Runs')
plt.figure(figsize=(12,6))
ax = sns.barplot(x='Total_Runs', y='Player_Names', data=top_runs, palette='Blues_r')

for i in ax.containers:
    ax.bar_label(i)
    
plt.title("Top 10 Run Scorers", fontsize=14)
plt.xlabel("Total Runs")
plt.ylabel("Player")
plt.show()

# %% [markdown]
# ### `Observation:-`
# - Sachin Tendulkar dominates with over 18,000 runs, far ahead of all other players, showing his unmatched consistency.
#
# - Kumar Sangakkara and Virat Kohli follow closely behind, both with over 14,000 runs, proving their exceptional performance.
#
# - The rest of the players (Ponting, Jayasuriya, Jayawardene, etc.) have impressive tallies between 11,000–13,000 runs, but there’s a noticeable gap compared to the top scorer.

# %% [markdown]
# ### Which country’s players have scored the highest total runs overall ?

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Country', y='Total_Runs', palette = "cool",data=df, estimator=np.sum, errorbar=None)
plt.xticks(rotation=60)
plt.title("Total Runs by Country (Sum)")
plt.show()

# %% [markdown]
# ### `Observation:-`
# - India dominates with the highest total runs, showing strong batting depth over time.
#
# - Sri Lanka, Australia, and Pakistan also have very high totals, forming the next strongest group.
#
# - Smaller cricket nations like Nepal, Oman, and UAE have much lower totals, highlighting fewer matches or less experience.

# %% [markdown]
# ### Top 10 Players by Centuries

# %%
top_100s = df.nlargest(10, "100's")
plt.figure(figsize=(10,6))
ax = sns.barplot(x="100's", y="Player_Names", data=top_100s, palette='Greens_r')

for i in ax.containers:
    ax.bar_label(i)
    
plt.title("Top 10 Players by Centuries", fontsize=14)
plt.xlabel("Centuries")
plt.ylabel("Player")
plt.show()

# %% [markdown]
# ### `Observation:-`
# - Top Performers: Virat Kohli and Sachin Tendulkar are clear leaders with 51 and 49 centuries, far ahead of others.
#
# - Mid-tier Group: Players like Rohit Sharma, Ponting, and Jayasuriya are in the 30–28 century range, showing consistent performance.
#
# - Close Competition: Several legends like Sangakkara, Gayle, and AB de Villiers are tied at 25 centuries, highlighting a competitive group.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert to datetime (assuming only year is given)
df['Start_Year'] = pd.to_datetime(df['Start_Year'], format='%Y', errors='coerce')
df['End_Year'] = pd.to_datetime(df['End_Year'], format='%Y', errors='coerce')

# Calculate career length in years
df['Career_Length'] = df['End_Year'].dt.year - df['Start_Year'].dt.year

# Create a year range for each player's active years
all_years = []
for i, row in df.iterrows():
    if pd.notnull(row['Start_Year']) and pd.notnull(row['End_Year']):
        all_years.extend(range(row['Start_Year'].year, row['End_Year'].year + 1))

# Count number of active players each year
yearly_counts = pd.Series(all_years).value_counts().sort_index()

# Plot trend
plt.figure(figsize=(12,6))
plt.plot(yearly_counts.index, yearly_counts.values, marker='o', linestyle='-', color='b')
plt.title("Number of Active Players Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Players Active")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.figure(figsize=(10,6))

sns.regplot(
    data=df,
    x='Matches',
    y='Total_Runs',
    scatter=False,       
    color='red',        
    line_kws={'linewidth':2}
)

sns.scatterplot(
    data=df,
    x='Matches',
    y='Total_Runs',
    hue='Country',        
    size='Batting_Average',
    alpha=0.7,
    sizes=(40, 400)
)

plt.title("Matches vs Total Runs (One Regression Line, Color=Country, Size=Batting Avg)", fontsize=14)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### `Observation:-`
# - Players with more matches generally score higher total runs, showing a strong positive relationship between career length and total performance.
#
# - Batting averages vary widely – some players maintain high averages even with fewer matches, while others achieve consistency over long careers.
#
# - Country-wise clustering is visible, with top cricketing nations dominating the higher runs and match counts compared to smaller cricket nations.

# %%
# heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Observation:-
# - Total runs increase mainly with matches and innings played.
#
# - Batting average and strike rate are largely independent of matches, innings, and total runs.
#
# - Strong correlations exist between Matches, Innings, and Total Runs, but not with performance efficiency metrics.

# %%
# Bubble Plot 
plt.figure(figsize=(12,7))
plt.scatter(top_df['Matches'], top_df['Total_Runs'],
            s=top_df['Strike_Rate']*2, alpha=0.6, edgecolors='black', c=top_df['Batting_Average'], cmap='plasma')
for i in range(top_df.shape[0]):
    plt.text(top_df['Matches'].iloc[i]+0.5, top_df['Total_Runs'].iloc[i],
             top_df['Player_Names'].iloc[i], fontsize=8)
plt.colorbar(label="Batting Average")
plt.xlabel("Matches")
plt.ylabel("Total Runs")
plt.title("Bubble Plot: Matches vs Runs (Color=Batting Avg, Size=Strike Rate)", fontsize=16)
plt.show()

# %% [markdown]
# ## Observation:-
# - More matches = more runs – Players who played more matches generally scored more runs.
#
# - Kohli has best average – Even with fewer matches, Virat Kohli has the highest batting average.
#
# - Big hitters have high strike rates – Players like Sehwag and Gayle score faster, shown by larger bubbles.
